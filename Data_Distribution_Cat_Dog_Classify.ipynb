# %%
import numpy as np
import matplotlib.pyplot as pp

sortdog = np.array([-267.310555637281,	-196.782818906248,	-187.619092423236,-180.202796730841,	-179.988808503513,	-178.640815954371,	-171.932872822204,	-170.512506127624,	-164.431068348057,	-142.467860426769,	-142.124371266068,	-139.888877963798,	-134.267119765627,	-132.163224322687,	-128.834351248722,	-127.981145293809,	-123.778031156339,	-121.947009803098,	-121.171661994677,	-120.177671919397,	-111.717331408654,	-108.930733010136,	-103.314828020752,	-98.9460911270739,	-98.1435146568970,	-92.9134322491037,	-89.9115495487194,	-89.6376901693724,	-87.6655328091938,	-85.4024851191644,	-83.3618896316920,	-83.3122351597626,	-81.0170722223915,	-77.3175130311029,	-76.6053428585142,	-73.7998713620907,	-73.3443640482385,	-66.6795563213732,	-63.3103997697301,	-62.1929556074935,	-61.5393415064273,	-60.9983662914001,	-60.2963540957428,	-58.5166942615459,	-45.1699270893788,	-40.0331010381749,	-38.1923881204266,	-35.0861823527265,	-19.4905186775701,	68.4410052153659])
sortcat = np.array([-100.768138705239,	-99.3907232226879,	-95.3602831167189,	-79.2491672470049,	-74.5373600101044,	-71.6425547295421,	-71.5159926006953,	-70.8116295974635,	-68.3864919948034,	-66.0296025521218,	-65.6607287634249,	-65.4235282832344,	-64.5174328590168,	-55.4230850792057,	-45.7033775351320,	-41.5131420735311,	-40.1346724892634,	-31.5900729497812,	-24.3441785131716,	-22.4976186289752,	-22.1990895255502,	-21.2391640832003,	-17.5284194948903,	-12.9171946193709,	-10.7280092298235,	-7.20849461011996,	-6.22248081077357,	-1.92973931569994,	2.43645478252555,	3.50170183504600,	5.06289276668862,	5.17076592208981,	5.34595111795193,	5.44814582996918,	5.53896623855190,	5.80171042490876,	8.28610094693656,	16.9761231046707,	18.5169005221808,	24.0868652425758,	27.1681456785120,	27.2343129022878,	27.8179736588743,	40.6442457883813,	44.8095382937594,	47.1546250941366,	51.1746541765823,	51.4468776508625,	53.9975366433815,	84.6961388493874])

# %%
val = 0
pp.plot(sortdog, np.zeros_like(sortdog) + val, 'x')
pp.plot(sortcat, np.zeros_like(sortcat) + val, 'o')
pp.show()

# %%
test_cat = np.array([-54.8144478752485,	-48.9493009839592,	-124.659326588420,	-32.7135065174544,	-110.351007460560,	-136.521717242497,	-6.97464652373726,	-42.8026924031000,	-87.3951401818663,	-117.296697529502])
test_dog = np.array([-85.3204902224428,	-44.6402718937700,	-100.407643243651,	-71.2266937166158,	-29.1263673162674,	2.43271393378674,	-43.7993014500892, -54.6170805094916,	33.2352691864124,	38.8189851427395])

# %%
val = 0
pp.plot(test_cat, np.zeros_like(test_cat) + val, 'x')
pp.plot(test_dog, np.zeros_like(test_dog) + val, 'o')
pp.show()
